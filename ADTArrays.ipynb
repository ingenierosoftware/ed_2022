# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenierosoftware/ed_2022/blob/main/ADTArrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
ADT Array.
ilysou df us uisdf ksdhf ksf
sdkufh dsufhsd
sdjkfhkds f
sd ifhsdlhf 
"""

class Array():
    def __init__(self, tamano):
        self.__tamano = tamano
        self.__data = [0 for x in range(self.__tamano)]  #generator

    def get_item( self , index ):
        return self.__data[index]

    def to_string(self):
        print(self.__data)

    def set_item(self,index , valor):
        if self.__check_limits__(index):
            self.__data[index]=valor
        else:
            raise Exception('Error de limites en index')

    def clear(self, valor):
        self.__data=[valor for x in range(self.__tamano)]

    def get_length( self  ):
        return self.__tamano
    
    def __check_limits__( self , index ):
        return index >=0 and index < self.__tamano

# %%
ejemplo = Array(5)
ejemplo.to_string()
ejemplo.get_item(3)
# Out:
# [0, 0, 0, 0, 0]
# 0

# %%
lista  = Array(10)

lista.set_item( 0 , 33 )
lista.set_item( 1 , 3 )
lista.set_item( 2 , 88 )
lista.set_item( 3 , 42 )
lista.set_item( 4 , 12 )
lista.set_item( 5 , 28 )
lista.set_item( 6 , 14 )
lista.set_item( 7 , 100 )
lista.set_item( 8 , 1 )
lista.set_item( 9 , 60 )

for indice in range( lista.get_length() ):
    print(lista.get_item( indice )  )

#lista.clear( -1 )


for indice in range( lista.get_length() ):
    print(lista.get_item( indice )  )
# Out:
# 33
# 3
# 88
# 42
# 12
# 28
# 14
# 100
# 1
# 60
# 33
# 3
# 88
# 42
# 12
# 28
# 14
# 100
# 1
# 60

# %% [markdown]
# # Métodos de búsqueda y ordenamiento.
#
#
# Búsqueda lineal.
# - De el recorrido desde la posicion 0 hasta la posición n-1 buscando un valor dado por el usuario.
#
# - Es un algritmo simple pero ineficiente.
#
# - No se sabe la complejidad por que depende de los datos internos

# %%
valor_a_buscar = int( input("¿Que valor quieres buscar?") )
encontrado = False
for indice in range( lista.get_length() ):
    if valor_a_buscar == lista.get_item( indice ):
        print("El lemento se encuentra en la posición:", indice)
        encontrado = True
        break

if encontrado :
    print("El elemento si existe en el arreglo")
else:
    print("El elemento no esta en el arreglo")
# Out:
# ¿Que valor quieres buscar?444
# El elemento no esta en el arreglo

# %% [markdown]
# # Método de ordenamiento de la burbuja

# %%
# !ls ./sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cat junio.dat
# Out:
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, año de ingreso
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
# 5754,ANGEL,GOMEZ,GARRIDO,1,9850,2020
# 5345,JESUS,MARTIN,SANTOS,2,9850,2016
# 3267,DAVID,JIMENEZ,LOZANO,2,9850,2017
# 8765,PEDRO,RUIZ,GUERRERO,2,9850,2017
# 5454,DANIEL,HERNANDEZ,CANO,3,9850,2018
# 3456,ALEJANDRO,DIAZ,PRIETO,2,9850,2018
# 3445,MARIA,MORENO,MENDEZ,1,9850,2018
# 9088,ALBERTO,MU�OZ,CRUZ,1,9850,2017
# 8877,RAFAEL,ALVAREZ,FLORES,2,9850,2017
# 6767,FERNANDO,ROMERO,HERRERA,4,9850,2019
# 5654,PABLO,ALONSO,GALLEGO,1,9850,2019
# 4323,JORGE,GUTIERREZ,MARQUEZ,2,9850,2020
# 2232,RAMON,NAVARRO,LEON,1,9850,2016

# %%
archivo = open('junio.dat','rt', encoding='latin-1') # 
print( archivo.read() )

"""
read() --> Lee todo el archivo y lo regresa comol un solo String(str)
readline()  --> Lee la siguiente linea hasta el sigueinte salto de linea (\n) 
                lo regresa, mueve el puntero al siguiente renglon
readlines() --> Lee todo el archivo lo separa por lineas y el resultado
                lo mete en un list de python.
"""
print(" Proband readline()")
archivo2 = open('junio.dat','rt', encoding='latin-1') # 
print( archivo2.readline() )
print( archivo2.readline() )

archivo3 = open('junio.dat','rt', encoding='latin-1') #
print("Probando readlines() ")
#print( archivo3.readlines() )
info = archivo3.readlines()

for index in range( len(info) ):
    info[index] = info[index].rstrip('\n').split(',')
    print(info[index])


print(info)
print("Sueldos")
for trab in info:
    print(trab[5])
# Out:
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, aÃ±o de ingreso
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
# 5754,ANGEL,GOMEZ,GARRIDO,1,9850,2020
# 5345,JESUS,MARTIN,SANTOS,2,9850,2016
# 3267,DAVID,JIMENEZ,LOZANO,2,9850,2017
# 8765,PEDRO,RUIZ,GUERRERO,2,9850,2017
# 5454,DANIEL,HERNANDEZ,CANO,3,9850,2018
# 3456,ALEJANDRO,DIAZ,PRIETO,2,9850,2018
# 3445,MARIA,MORENO,MENDEZ,1,9850,2018
# 9088,ALBERTO,MUOZ,CRUZ,1,9850,2017
# 8877,RAFAEL,ALVAREZ,FLORES,2,9850,2017
# 6767,FERNANDO,ROMERO,HERRERA,4,9850,2019
# 5654,PABLO,ALONSO,GALLEGO,1,9850,2019
# 4323,JORGE,GUTIERREZ,MARQUEZ,2,9850,2020
# 2232,RAMON,NAVARRO,LEON,1,9850,2016
#  Proband readline()
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, aÃ±o de ingreso
#
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
#
# Probando readlines()
# ['numero de trabajador', ' nombres', ' paterno', ' materno', ' horas extra', ' sueldo base', ' aÃ±o de ingreso']
# ['2345', 'CARLOS', 'PEREZ', 'CASTILLO', '0', '9850', '2017']
# ['5754', 'ANGEL', 'GOMEZ', 'GARRIDO', '1', '9850', '2020']
# ['5345', 'JESUS', 'MARTIN', 'SANTOS', '2', '9850', '2016']
# ['3267', 'DAVID', 'JIMENEZ', 'LOZANO', '2', '9850', '2017']
# ['8765', 'PEDRO', 'RUIZ', 'GUERRERO', '2', '9850', '2017']
# ['5454', 'DANIEL', 'HERNANDEZ', 'CANO', '3', '9850', '2018']
# ['3456', 'ALEJANDRO', 'DIAZ', 'PRIETO', '2', '9850', '2018']
# ['3445', 'MARIA', 'MORENO', 'MENDEZ', '1', '9850', '2018']
# ['9088', 'ALBERTO', 'MU\x84OZ', 'CRUZ', '1', '9850', '2017']
# ['8877', 'RAFAEL', 'ALVAREZ', 'FLORES', '2', '9850', '2017']
# ['6767', 'FERNANDO', 'ROMERO', 'HERRERA', '4', '9850', '2019']
# ['5654', 'PABLO', 'ALONSO', 'GALLEGO', '1', '9850', '2019']
# ['4323', 'JORGE', 'GUTIERREZ', 'MARQUEZ', '2', '9850', '2020']
# ['2232', 'RAMON', 'NAVARRO', 'LEON', '1', '9850', '2016']
# [['numero de trabajador', ' nombres', ' paterno', ' materno', ' horas extra', ' sueldo base', ' aÃ±o de ingreso'], ['2345', 'CARLOS', 'PEREZ', 'CASTILLO', '0', '9850', '2017'], ['5754', 'ANGEL', 'GOMEZ', 'GARRIDO', '1', '9850', '2020'], ['5345', 'JESUS', 'MARTIN', 'SANTOS', '2', '9850', '2016'], ['3267', 'DAVID', 'JIMENEZ', 'LOZANO', '2', '9850', '2017'], ['8765', 'PEDRO', 'RUIZ', 'GUERRERO', '2', '9850', '2017'], ['5454', 'DANIEL', 'HERNANDEZ', 'CANO', '3', '9850', '2018'], ['3456', 'ALEJANDRO', 'DIAZ', 'PRIETO', '2', '9850', '2018'], ['3445', 'MARIA', 'MORENO', 'MENDEZ', '1', '9850', '2018'], ['9088', 'ALBERTO', 'MU\x84OZ', 'CRUZ', '1', '9850', '2017'], ['8877', 'RAFAEL', 'ALVAREZ', 'FLORES', '2', '9850', '2017'], ['6767', 'FERNANDO', 'ROMERO', 'HERRERA', '4', '9850', '2019'], ['5654', 'PABLO', 'ALONSO', 'GALLEGO', '1', '9850', '2019'], ['4323', 'JORGE', 'GUTIERREZ', 'MARQUEZ', '2', '9850', '2020'], ['2232', 'RAMON', 'NAVARRO', 'LEON', '1', '9850', '2016']]
# Sueldos
#  sueldo base
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850
# 9850

# %%
class Trabajador:
    def __init_( self , nt , nom , pat , mat , h_extra , sueldo , anio_ingreso):
        self.num_trabajador = nt
        self.nombre = nom
        self.paterno = pat
        self.mat = mat
        self.horas_extra = h_extra
        self.sueldo = sueldo
        self.anio_ingreso = anio_ingreso
    
    def set_num_trabajador( self , nt):
        self.num_trabajador

    def get_num_trabajador( self ):
        return self.num_trabajador

    # aqui van los demas get and set

    # poner metodos de uso general

# %%
class Empresa:
    def __init__( self ):
        # codigo para leer el archivo, podria ser un metodo local
        self.empleados = Array(14)
        # codigo para crear un objeto por cada linea leida del archivo y meterlo al array.

    def calcular_sueldos( self ):
        # codigo para recorrer self.empleados y mostrar lo que se pide los sueldos con las reglas

    def encontrar_mayor_ant( self ):
        # codigo para calcular al mas antiguo y mostrao en pantalla
